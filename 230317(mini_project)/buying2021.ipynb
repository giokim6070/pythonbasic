# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
df = pd.read_excel("C:/python/datas/단독다가구(매매)_실거래가.xlsx")
df
# Out:
# C:\Users\giokim\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 0    □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN        NaN
# 1    □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN        NaN
# 2    □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4    * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN        NaN
# ..                                                 ...        ...        ...
# 506                                      서울특별시 중랑구 중화동        4**        다가구
# 507                                      서울특별시 중랑구 중화동        3**         단독
# ...

# %%
df.drop(df.index[0:16], inplace=True)
df
# Out:
#     □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 16                                       서울특별시 강남구 논현동        1**        다가구
# 17                                       서울특별시 강남구 논현동        1**        다가구
# 18                                       서울특별시 강남구 논현동         2*        다가구
# 19                                       서울특별시 강남구 논현동        2**         단독
# 20                                       서울특별시 강남구 논현동        2**         단독
# ..                                                 ...        ...        ...
# 506                                      서울특별시 중랑구 중화동        4**        다가구
# 507                                      서울특별시 중랑구 중화동        3**         단독
# 508                                      서울특별시 중랑구 중화동        3**         단독
# 509                                      서울특별시 중랑구 중화동        3**         단독
# 510                                      서울특별시 중랑구 중화동        3**         단독
#
# ...

# %%
df.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 8': '거래금액(만원)'}, inplace=True)

del df['Unnamed: 1']
del df['Unnamed: 2']
del df['Unnamed: 3']
del df['Unnamed: 4']
del df['Unnamed: 5']
del df['Unnamed: 6']
del df['Unnamed: 7']
del df['Unnamed: 9']
del df['Unnamed: 10']
del df['Unnamed: 11']
del df['Unnamed: 12']
del df['Unnamed: 13']
df
# Out:
#                시군구        거래금액(만원)
# 16   서울특별시 강남구 논현동         530,000
# 17   서울특별시 강남구 논현동         360,000
# 18   서울특별시 강남구 논현동       2,000,000
# 19   서울특별시 강남구 논현동         285,000
# 20   서울특별시 강남구 논현동         330,000
# ..             ...             ...
# 506  서울특별시 중랑구 중화동         110,000
# 507  서울특별시 중랑구 중화동          54,191
# 508  서울특별시 중랑구 중화동          48,640
# 509  서울특별시 중랑구 중화동         129,700
# 510  서울특별시 중랑구 중화동         117,300
#
# [495 rows x 2 columns]

# %%
df10 = df[['시군구', '거래금액(만원)']]
df10
# Out:
#                시군구        거래금액(만원)
# 16   서울특별시 강남구 논현동         530,000
# 17   서울특별시 강남구 논현동         360,000
# 18   서울특별시 강남구 논현동       2,000,000
# 19   서울특별시 강남구 논현동         285,000
# 20   서울특별시 강남구 논현동         330,000
# ..             ...             ...
# 506  서울특별시 중랑구 중화동         110,000
# 507  서울특별시 중랑구 중화동          54,191
# 508  서울특별시 중랑구 중화동          48,640
# 509  서울특별시 중랑구 중화동         129,700
# 510  서울특별시 중랑구 중화동         117,300
#
# [495 rows x 2 columns]

# %%
df10['거래금액(만원)'] = df10['거래금액(만원)'].str.replace(',', '').astype('int64')

# %%
df10['시군구'] = df10['시군구'].str.split().str[1]
df10
# Out:
#      시군구  거래금액(만원)
# 16   강남구    530000
# 17   강남구    360000
# 18   강남구   2000000
# 19   강남구    285000
# 20   강남구    330000
# ..   ...       ...
# 506  중랑구    110000
# 507  중랑구     54191
# 508  중랑구     48640
# 509  중랑구    129700
# 510  중랑구    117300
#
# [495 rows x 2 columns]

# %%
round(df10.groupby('시군구').mean(),2)
# Out:
#        거래금액(만원)
# 시군구
# 강남구   899500.00
# 강동구   249696.64
# 강북구   137557.74
# 강서구   136248.00
# 관악구   169977.29
# 광진구   177113.04
# 구로구    89313.85
# 금천구    88444.74
# 노원구   193112.50
# 도봉구    70784.62
# 동대문구  114476.67
# 동작구   159701.37
# 마포구   247246.07
# 서대문구  132638.89
# 서초구   353056.13
# 성동구   361725.00
# 성북구   131651.93
# 송파구   280486.67
# 양천구   123136.25
# 영등포구  104387.89
# 용산구   244236.92
# 은평구   116841.05
# 종로구   136808.47
# 중구    144119.54
# 중랑구    96133.26

# %%
df2 = pd.read_excel("C:/python/datas/아파트(매매)_실거래가.xlsx")
df2
# Out:
# C:\Users\giokim\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 0     □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN        NaN
# 1     □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN        NaN
# 2     □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN        NaN
# 3                                                   NaN        NaN        NaN
# 4     * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN        NaN
# ...                                                 ...        ...        ...
# 1188                                      서울특별시 중랑구 신내동        657       0657
# 1189                                      서울특별시 중랑구 중화동        454       0454
# ...

# %%
df2.drop(df2.index[0:16], inplace=True)
df2
# Out:
#      □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 16                                        서울특별시 강남구 개포동      658-1       0658
# 17                                        서울특별시 강남구 개포동        138       0138
# 18                                        서울특별시 강남구 개포동       1280       1280
# 19                                        서울특별시 강남구 개포동         12       0012
# 20                                        서울특별시 강남구 개포동        653       0653
# ...                                                 ...        ...        ...
# 1188                                      서울특별시 중랑구 신내동        657       0657
# 1189                                      서울특별시 중랑구 중화동        454       0454
# 1190                                      서울특별시 중랑구 중화동     286-22       0286
# 1191                                      서울특별시 중랑구 중화동     286-22       0286
# 1192                                      서울특별시 중랑구 중화동       19-3       0019
#
# ...

# %%
df2.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 8': '거래금액(만원)'}, inplace=True)

del df2['Unnamed: 1']
del df2['Unnamed: 2']
del df2['Unnamed: 3']
del df2['Unnamed: 4']
del df2['Unnamed: 5']
del df2['Unnamed: 6']
del df2['Unnamed: 7']
del df2['Unnamed: 9']
del df2['Unnamed: 10']
del df2['Unnamed: 11']
del df2['Unnamed: 12']
del df2['Unnamed: 13']
del df2['Unnamed: 14']
df2
# Out:
#                 시군구        거래금액(만원)
# 16    서울특별시 강남구 개포동         215,000
# 17    서울특별시 강남구 개포동         235,000
# 18    서울특별시 강남구 개포동         316,000
# 19    서울특별시 강남구 개포동         150,000
# 20    서울특별시 강남구 개포동         355,000
# ...             ...             ...
# 1188  서울특별시 중랑구 신내동          42,400
# 1189  서울특별시 중랑구 중화동          96,000
# 1190  서울특별시 중랑구 중화동          77,500
# 1191  서울특별시 중랑구 중화동          69,500
# 1192  서울특별시 중랑구 중화동          32,500
#
# [1177 rows x 2 columns]

# %%
df11 = df2[['시군구', '거래금액(만원)']]
df11
# Out:
#                 시군구        거래금액(만원)
# 16    서울특별시 강남구 개포동         215,000
# 17    서울특별시 강남구 개포동         235,000
# 18    서울특별시 강남구 개포동         316,000
# 19    서울특별시 강남구 개포동         150,000
# 20    서울특별시 강남구 개포동         355,000
# ...             ...             ...
# 1188  서울특별시 중랑구 신내동          42,400
# 1189  서울특별시 중랑구 중화동          96,000
# 1190  서울특별시 중랑구 중화동          77,500
# 1191  서울특별시 중랑구 중화동          69,500
# 1192  서울특별시 중랑구 중화동          32,500
#
# [1177 rows x 2 columns]

# %%
df11['거래금액(만원)'] = df11['거래금액(만원)'].str.replace(',', '').astype('int64')

# %%
df11['시군구'] = df11['시군구'].str.split().str[1]
df11
# Out:
#       시군구  거래금액(만원)
# 16    강남구    215000
# 17    강남구    235000
# 18    강남구    316000
# 19    강남구    150000
# 20    강남구    355000
# ...   ...       ...
# 1188  중랑구     42400
# 1189  중랑구     96000
# 1190  중랑구     77500
# 1191  중랑구     69500
# 1192  중랑구     32500
#
# [1177 rows x 2 columns]

# %%
round(df11.groupby('시군구').mean(),2)
# Out:
#        거래금액(만원)
# 시군구
# 강남구   240087.67
# 강동구    98281.62
# 강북구    50653.85
# 강서구    75942.86
# 관악구    64072.55
# 광진구   119044.44
# 구로구    50109.03
# 금천구    54725.00
# 노원구    72394.92
# 도봉구    63753.95
# 동대문구   63791.30
# 동작구   105008.75
# 마포구   121646.09
# 서대문구   87746.05
# 서초구   195370.89
# 성동구   146516.67
# 성북구    75606.63
# 송파구   136440.30
# 양천구   118074.51
# 영등포구   93438.81
# 용산구   236308.00
# 은평구    71924.17
# 종로구    82650.00
# 중구     84205.56
# 중랑구    63194.57

# %%
df3 = pd.read_excel("C:/python/datas/연립다세대(매매)_실거래가.xlsx")
df3
# Out:
# C:\Users\giokim\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 0     □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN        NaN
# 1     □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN        NaN
# 2     □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN        NaN
# 3                                                   NaN        NaN        NaN
# 4     * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN        NaN
# ...                                                 ...        ...        ...
# 3604                                      서울특별시 중랑구 중화동     309-24       0309
# 3605                                      서울특별시 중랑구 중화동     306-11       0306
# ...

# %%
df3.drop(df3.index[0:16], inplace=True)
df3
# Out:
#      □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 16                                        서울특별시 강남구 개포동     1187-8       1187
# 17                                        서울특별시 강남구 개포동    1218-12       1218
# 18                                        서울특별시 강남구 개포동    1218-12       1218
# 19                                        서울특별시 강남구 개포동    1218-12       1218
# 20                                        서울특별시 강남구 개포동    1218-12       1218
# ...                                                 ...        ...        ...
# 3604                                      서울특별시 중랑구 중화동     309-24       0309
# 3605                                      서울특별시 중랑구 중화동     306-11       0306
# 3606                                      서울특별시 중랑구 중화동    309-109       0309
# 3607                                      서울특별시 중랑구 중화동    309-109       0309
# 3608                                      서울특별시 중랑구 중화동       90-7       0090
#
# ...

# %%
df3.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 9': '거래금액(만원)'}, inplace=True)

del df3['Unnamed: 1']
del df3['Unnamed: 2']
del df3['Unnamed: 3']
del df3['Unnamed: 4']
del df3['Unnamed: 5']
del df3['Unnamed: 6']
del df3['Unnamed: 7']
del df3['Unnamed: 8']
del df3['Unnamed: 10']
del df3['Unnamed: 11']
del df3['Unnamed: 12']
del df3['Unnamed: 13']
del df3['Unnamed: 14']
del df3['Unnamed: 15']
df3
# Out:
#                 시군구        거래금액(만원)
# 16    서울특별시 강남구 개포동          75,000
# 17    서울특별시 강남구 개포동          42,500
# 18    서울특별시 강남구 개포동          42,000
# 19    서울특별시 강남구 개포동          42,500
# 20    서울특별시 강남구 개포동          42,700
# ...             ...             ...
# 3604  서울특별시 중랑구 중화동          37,500
# 3605  서울특별시 중랑구 중화동          23,000
# 3606  서울특별시 중랑구 중화동          30,000
# 3607  서울특별시 중랑구 중화동          21,000
# 3608  서울특별시 중랑구 중화동          32,000
#
# [3593 rows x 2 columns]

# %%
df12 = df3[['시군구', '거래금액(만원)']]
df12
# Out:
#                 시군구        거래금액(만원)
# 16    서울특별시 강남구 개포동          75,000
# 17    서울특별시 강남구 개포동          42,500
# 18    서울특별시 강남구 개포동          42,000
# 19    서울특별시 강남구 개포동          42,500
# 20    서울특별시 강남구 개포동          42,700
# ...             ...             ...
# 3604  서울특별시 중랑구 중화동          37,500
# 3605  서울특별시 중랑구 중화동          23,000
# 3606  서울특별시 중랑구 중화동          30,000
# 3607  서울특별시 중랑구 중화동          21,000
# 3608  서울특별시 중랑구 중화동          32,000
#
# [3593 rows x 2 columns]

# %%
df4 = pd.read_excel("C:/Users/giokim/Desktop/real_estate/오피스텔(매매)_실거래가_20230319.xlsx")
df4

# %%
df4.drop(df4.index[0:16], inplace=True)
df4

# %%
df4.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 8': '거래금액(만원)'}, inplace=True)

del df4['Unnamed: 1']
del df4['Unnamed: 2']
del df4['Unnamed: 3']
del df4['Unnamed: 4']
del df4['Unnamed: 5']
del df4['Unnamed: 6']
del df4['Unnamed: 7']
del df4['Unnamed: 9']
del df4['Unnamed: 10']
del df4['Unnamed: 11']
del df4['Unnamed: 12']
del df4['Unnamed: 13']
del df4['Unnamed: 14']
df4
