# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
df = pd.read_excel("C:/python/datas/단독다가구(전월세)_실거래가_20230319004709.xlsx")
df
# Out:
# C:\Users\giokim\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 0       □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN
# 1       □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN
# 2       □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN
# 3                                                     NaN        NaN
# 4       * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN
# ...                                                   ...        ...
# 162052                                      서울특별시 중랑구 중화동        1**
# 162053                                      서울특별시 중랑구 중화동        1**
# 162054                                      서울특별시 중랑구 중화동        3**
# ...

# %%
df.drop(df.index[0:16], inplace=True)
df
# Out:
#        □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 16                                          서울특별시 강남구 개포동        1**
# 17                                          서울특별시 강남구 개포동       1***
# 18                                          서울특별시 강남구 개포동       1***
# 19                                          서울특별시 강남구 개포동       1***
# 20                                          서울특별시 강남구 개포동       1***
# ...                                                   ...        ...
# 162052                                      서울특별시 중랑구 중화동        1**
# 162053                                      서울특별시 중랑구 중화동        1**
# 162054                                      서울특별시 중랑구 중화동        3**
# 162055                                      서울특별시 중랑구 중화동        1**
# 162056                                      서울특별시 중랑구 중화동        2**
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6      Unnamed: 7  \
# ...

# %%
df.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 4': '전월세구분',
                     'Unnamed: 7': '보증금(만원)',
                     'Unnamed: 8': '월세(만원)'}, inplace=True)

del df['Unnamed: 1']
del df['Unnamed: 2']
del df['Unnamed: 3']
del df['Unnamed: 5']
del df['Unnamed: 6']
del df['Unnamed: 9']
del df['Unnamed: 10']
del df['Unnamed: 11']
del df['Unnamed: 12']
del df['Unnamed: 13']
del df['Unnamed: 14']
del df['Unnamed: 15']
df
# Out:
#                   시군구 전월세구분         보증금(만원)          월세(만원)
# 16      서울특별시 강남구 개포동    월세             300              10
# 17      서울특별시 강남구 개포동    월세             500              35
# 18      서울특별시 강남구 개포동    월세             300              35
# 19      서울특별시 강남구 개포동    월세             500              45
# 20      서울특별시 강남구 개포동    월세             500              35
# ...               ...   ...             ...             ...
# 162052  서울특별시 중랑구 중화동    월세           5,000              35
# 162053  서울특별시 중랑구 중화동    월세           3,000              35
# 162054  서울특별시 중랑구 중화동    월세          23,000              30
# 162055  서울특별시 중랑구 중화동    월세           3,000              30
# 162056  서울특별시 중랑구 중화동    월세           2,000              40
#
# [162041 rows x 4 columns]

# %%
df2 = pd.read_excel("C:/python/datas/아파트(전월세)_실거래가_20230319004139.xlsx")
df2
# Out:
# C:\Users\giokim\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 0      □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN
# 1      □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN
# 2      □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN
# 3                                                    NaN        NaN
# 4      * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN
# ...                                                  ...        ...
# 23183                                      서울특별시 중랑구 중화동        450
# 23184                                      서울특별시 중랑구 중화동        450
# 23185                                      서울특별시 중랑구 중화동        450
# ...

# %%
df2.drop(df2.index[0:16], inplace=True)
df2
# Out:
#       □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 16                                         서울특별시 강남구 개포동      658-1
# 17                                         서울특별시 강남구 개포동      658-1
# 18                                         서울특별시 강남구 개포동      651-1
# 19                                         서울특별시 강남구 개포동      651-1
# 20                                         서울특별시 강남구 개포동      651-1
# ...                                                  ...        ...
# 23183                                      서울특별시 중랑구 중화동        450
# 23184                                      서울특별시 중랑구 중화동        450
# 23185                                      서울특별시 중랑구 중화동        450
# 23186                                      서울특별시 중랑구 중화동        450
# 23187                                      서울특별시 중랑구 중화동        450
#
#       Unnamed: 2 Unnamed: 3      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
df2.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 5': '전월세구분',
                     'Unnamed: 9': '보증금(만원)',
                     'Unnamed: 10': '월세(만원)'}, inplace=True)

del df2['Unnamed: 1']
del df2['Unnamed: 2']
del df2['Unnamed: 3']
del df2['Unnamed: 4']
del df2['Unnamed: 6']
del df2['Unnamed: 7']
del df2['Unnamed: 8']
del df2['Unnamed: 11']
del df2['Unnamed: 12']
del df2['Unnamed: 13']
del df2['Unnamed: 14']
del df2['Unnamed: 15']
del df2['Unnamed: 16']
del df2['Unnamed: 17']
del df2['Unnamed: 18']
df2
# Out:
#                  시군구 전월세구분         보증금(만원)          월세(만원)
# 16     서울특별시 강남구 개포동    전세          36,000               0
# 17     서울특별시 강남구 개포동    전세          60,000               0
# 18     서울특별시 강남구 개포동    월세          20,000             535
# 19     서울특별시 강남구 개포동    월세          40,000             410
# 20     서울특별시 강남구 개포동    전세         200,000               0
# ...              ...   ...             ...             ...
# 23183  서울특별시 중랑구 중화동    전세          27,000               0
# 23184  서울특별시 중랑구 중화동    전세          37,800               0
# 23185  서울특별시 중랑구 중화동    월세          10,000              63
# 23186  서울특별시 중랑구 중화동    월세          10,000              63
# 23187  서울특별시 중랑구 중화동    전세          31,500               0
#
# [23172 rows x 4 columns]

# %%
df3 = pd.read_excel("C:/python/datas/연립다세대(전월세)_실거래가_20230319004255.xlsx")
df3
# Out:
# C:\Users\giokim\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 0      □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN
# 1      □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN
# 2      □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN
# 3                                                    NaN        NaN
# 4      * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN
# ...                                                  ...        ...
# 11254                                      서울특별시 중랑구 중화동    320-102
# 11255                                      서울특별시 중랑구 중화동    320-102
# 11256                                      서울특별시 중랑구 중화동     322-48
# ...

# %%
df3.drop(df3.index[0:16], inplace=True)
df3
# Out:
#       □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 16                                         서울특별시 강남구 개포동    1164-27
# 17                                         서울특별시 강남구 개포동    1164-27
# 18                                         서울특별시 강남구 개포동    1183-12
# 19                                         서울특별시 강남구 개포동     1252-8
# 20                                         서울특별시 강남구 개포동       1213
# ...                                                  ...        ...
# 11254                                      서울특별시 중랑구 중화동    320-102
# 11255                                      서울특별시 중랑구 중화동    320-102
# 11256                                      서울특별시 중랑구 중화동     322-48
# 11257                                      서울특별시 중랑구 중화동     110-39
# 11258                                      서울특별시 중랑구 중화동     110-39
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 16          1164       0027  (1164-27)         월세      51.78     202112
# ...

# %%
df3.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 5': '전월세구분',
                     'Unnamed: 9': '보증금(만원)',
                     'Unnamed: 10': '월세(만원)'}, inplace=True)

del df3['Unnamed: 1']
del df3['Unnamed: 2']
del df3['Unnamed: 3']
del df3['Unnamed: 4']
del df3['Unnamed: 6']
del df3['Unnamed: 7']
del df3['Unnamed: 8']
del df3['Unnamed: 11']
del df3['Unnamed: 12']
del df3['Unnamed: 13']
del df3['Unnamed: 14']
del df3['Unnamed: 15']
del df3['Unnamed: 16']
del df3['Unnamed: 17']
del df3['Unnamed: 18']
df3
# Out:
#                  시군구 전월세구분         보증금(만원)          월세(만원)
# 16     서울특별시 강남구 개포동    월세          50,000               6
# 17     서울특별시 강남구 개포동    월세          50,000               6
# 18     서울특별시 강남구 개포동    월세          10,000             200
# 19     서울특별시 강남구 개포동    전세          39,600               0
# 20     서울특별시 강남구 개포동    월세          38,000              30
# ...              ...   ...             ...             ...
# 11254  서울특별시 중랑구 중화동    전세          18,350               0
# 11255  서울특별시 중랑구 중화동    전세          18,000               0
# 11256  서울특별시 중랑구 중화동    월세           1,000              63
# 11257  서울특별시 중랑구 중화동    전세          32,500               0
# 11258  서울특별시 중랑구 중화동    전세          32,500               0
#
# [11243 rows x 4 columns]

# %%
df4 = pd.read_excel("C:/python/datas/오피스텔(전월세)_실거래가_20230319.xlsx")
df4
# Out:
# C:\Users\giokim\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 0      □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN
# 1      □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN
# 2      □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN
# 3                                                    NaN        NaN
# 4      * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN
# ...                                                  ...        ...
# 61609                                      서울특별시 중랑구 중화동      208-4
# 61610                                      서울특별시 중랑구 중화동      208-4
# 61611                                      서울특별시 중랑구 중화동      208-4
# ...

# %%
df4.drop(df4.index[0:16], inplace=True)
df4
# Out:
#       □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1  \
# 16                                         서울특별시 강남구 개포동      157-9
# 17                                         서울특별시 강남구 개포동      157-9
# 18                                         서울특별시 강남구 개포동      157-9
# 19                                         서울특별시 강남구 개포동     1237-3
# 20                                         서울특별시 강남구 개포동     1237-3
# ...                                                  ...        ...
# 61609                                      서울특별시 중랑구 중화동      208-4
# 61610                                      서울특별시 중랑구 중화동      208-4
# 61611                                      서울특별시 중랑구 중화동      208-4
# 61612                                      서울특별시 중랑구 중화동     305-59
# 61613                                      서울특별시 중랑구 중화동      307-4
#
#       Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 16          0157       0009  \t(157-9)\t         전세      29.25     202102
# ...

# %%
df4.rename(columns = {'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.': '시군구', 
                     'Unnamed: 5': '전월세구분',
                     'Unnamed: 9': '보증금(만원)',
                     'Unnamed: 10': '월세(만원)'}, inplace=True)

del df4['Unnamed: 1']
del df4['Unnamed: 2']
del df4['Unnamed: 3']
del df4['Unnamed: 4']
del df4['Unnamed: 6']
del df4['Unnamed: 7']
del df4['Unnamed: 8']
del df4['Unnamed: 11']
del df4['Unnamed: 12']
del df4['Unnamed: 13']
del df4['Unnamed: 14']
del df4['Unnamed: 15']
del df4['Unnamed: 16']
del df4['Unnamed: 17']
del df4['Unnamed: 18']
df4
# Out:
#                  시군구 전월세구분         보증금(만원)          월세(만원)
# 16     서울특별시 강남구 개포동    전세          15,000               0
# 17     서울특별시 강남구 개포동    전세          24,000               0
# 18     서울특별시 강남구 개포동    전세          20,000               0
# 19     서울특별시 강남구 개포동    월세           3,000             100
# 20     서울특별시 강남구 개포동    월세           3,000             105
# ...              ...   ...             ...             ...
# 61609  서울특별시 중랑구 중화동    월세           2,000              45
# 61610  서울특별시 중랑구 중화동    월세           1,000              45
# 61611  서울특별시 중랑구 중화동    월세           1,000              50
# 61612  서울특별시 중랑구 중화동    월세           1,000              50
# 61613  서울특별시 중랑구 중화동    전세           5,500               0
#
# [61598 rows x 4 columns]
