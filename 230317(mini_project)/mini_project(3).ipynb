# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium
import json
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
df = pd.read_csv("C:/python/datas/crime_datas")
df.head()
# Out:
#    Unnamed: 0   구별   발생 합계   검거 합계  살인 발생  강도 발생  강간, 강제추행 발생   절도 발생   폭력 발생  \
# 0           0  강남구  6146.0  4397.0   12.0   25.0        578.0  2372.0  3159.0
# 1           1  강동구  3458.0  2462.0    3.0    6.0        124.0  1612.0  1713.0
# 2           2  강북구  2301.0  1912.0    4.0    1.0        136.0   777.0  1383.0
# 3           3  강서구  3896.0  3044.0    9.0    3.0        246.0  1540.0  2098.0
# 4           4  관악구  4444.0  3134.0    8.0    7.0        321.0  1860.0  2248.0
#
#    강간, 강제추행 검거율   강도검거율   살인검거율  절도검거율  폭력검거율     검거율 합계     인구수
# 0         78.55   92.00   91.67  48.90  87.02  71.542467  581760
# 1         83.06  100.00  100.00  55.15  85.29  71.197224  463321
# 2         84.56  100.00  100.00  69.11  90.74  83.094307  334426
# 3         76.42  100.00   77.78  59.81  91.75  78.131417  595691
# 4         83.80   85.71   50.00  49.95  85.68  70.522052  529031

# %%
del df['Unnamed: 0']

# %%
df.rename(columns = {'살인 발생': '살인', 
                     '강도 발생': '강도',
                     '강간, 강제추행 발생': '강간, 강제추행',
                     '절도 발생': '절도',
                     '폭력 발생': '폭력'}, inplace=True)
del df['발생 합계']
del df['검거 합계']
df
# Out:
#       구별    살인    강도  강간, 강제추행      절도      폭력  강간, 강제추행 검거율   강도검거율   살인검거율  \
# 0    강남구  12.0  25.0     578.0  2372.0  3159.0         78.55   92.00   91.67
# 1    강동구   3.0   6.0     124.0  1612.0  1713.0         83.06  100.00  100.00
# 2    강북구   4.0   1.0     136.0   777.0  1383.0         84.56  100.00  100.00
# 3    강서구   9.0   3.0     246.0  1540.0  2098.0         76.42  100.00   77.78
# 4    관악구   8.0   7.0     321.0  1860.0  2248.0         83.80   85.71   50.00
# 5    광진구   5.0   4.0     208.0  1414.0  1456.0         77.40  100.00   60.00
# 6    구로구   5.0   2.0     182.0  1390.0  1907.0         64.84   50.00  100.00
# 7    금천구   7.0   3.0     134.0  1013.0  1282.0         76.87  100.00   85.71
# 8    노원구   6.0   3.0     156.0  1361.0  1899.0         80.77  100.00  100.00
# 9    도봉구   2.0   2.0      72.0   772.0  1012.0         88.89   50.00  100.00
# 10  동대문구   3.0   7.0     169.0  1240.0  1540.0         86.98  100.00  100.00
# 11   동작구   2.0   1.0     180.0  1129.0  1319.0         52.22  100.00  100.00
# 12   마포구   4.0   4.0     321.0  1510.0  1701.0         85.67  100.00   75.00
# 13  서대문구   3.0   2.0     137.0  1027.0  1109.0         87.59  100.00  100.00
# 14   서초구   9.0   5.0     312.0  1503.0  1827.0         73.08  100.00  100.00
# 15   성동구   3.0   4.0     110.0   905.0  1090.0         74.55   25.00  100.00
# 16   성북구   4.0   2.0     118.0   895.0  1392.0         74.58  100.00   75.00
# 17   송파구   3.0   7.0     247.0  2024.0  2433.0         87.45   85.71  100.00
# 18   양천구   1.0   3.0     116.0  1349.0  1546.0         79.31  100.00  100.00
# 19  영등포구   8.0  11.0     279.0  1712.0  2169.0         70.25  100.00  100.00
# 20   용산구   3.0   1.0     141.0   945.0  1291.0         73.05  100.00   66.67
# 21   은평구   4.0   3.0     166.0  1424.0  1647.0         80.12  100.00  100.00
# 22   종로구   6.0   4.0     156.0  1079.0  1467.0        100.00  100.00   50.00
# 23    중구   6.0   6.0     161.0  1279.0  1409.0         60.25  100.00  100.00
# 24   중랑구   4.0   6.0     141.0  1399.0  1660.0         82.98  100.00  100.00
#
#     절도검거율  폭력검거율      검거율 합계     인구수
# 0   48.90  87.02   71.542467  581760
# 1   55.15  85.29   71.197224  463321
# 2   69.11  90.74   83.094307  334426
# 3   59.81  91.75   78.131417  595691
# 4   49.95  85.68   70.522052  529031
# 5   53.32  87.91   71.331390  375180
# 6   55.40  80.60   69.736087  454604
# 7   51.33  86.43   71.381714  256167
# 8   48.05  79.67   67.211679  578221
# 9   48.70  84.09   69.569892  353241
# 10  53.15  84.09   71.409260  373824
# 11  59.79  80.06   69.517294  412774
# 12  48.34  80.36   67.203390  398351
# 13  54.72  81.79   69.973661  323105
# 14  45.97  82.43   66.712254  451258
# 15  54.92  84.95   71.496212  305065
# 16  52.96  87.64   74.118623  469560
# 17  49.16  84.09   69.282987  667480
# 18  51.89  83.38   69.154229  489010
# 19  48.54  79.81   66.451304  417811
# 20  51.22  82.80   69.676606  247909
# 21  57.94  88.46   74.691739  502578
# 22  68.86  85.07  101.585546  163822
# 23  57.78  86.87   72.422230  134329
# 24  59.69  86.87   74.922118  418620

# %%
target_col = ['살인', '강도', '강간, 강제추행', '절도', '폭력']
weight_col = df[target_col].max()

crime_count_norm = df[target_col]/weight_col
crime_count_norm.head()
# Out:
#          살인    강도  강간, 강제추행        절도        폭력
# 0  1.000000  1.00  1.000000  1.000000  1.000000
# 1  0.250000  0.24  0.214533  0.679595  0.542260
# 2  0.333333  0.04  0.235294  0.327572  0.437797
# 3  0.750000  0.12  0.425606  0.649241  0.664134
# 4  0.666667  0.28  0.555363  0.784148  0.711618

# %%
df.set_index('구별', inplace=True)
df
# Out:
#         살인    강도  강간, 강제추행      절도      폭력  강간, 강제추행 검거율   강도검거율   살인검거율  \
# 구별
# 강남구   12.0  25.0     578.0  2372.0  3159.0         78.55   92.00   91.67
# 송파구   49.16  84.09   69.282987  667480
# 양천구   51.89  83.38   69.154229  489010
# 영등포구  48.54  79.81   66.451304  417811
# 용산구   51.22  82.80   69.676606  247909
# 은평구   57.94  88.46   74.691739  502578
# 종로구   68.86  85.07  101.585546  163822
# 중구    57.78  86.87   72.422230  134329
# 중랑구   59.69  86.87   74.922118  418620

# %%
df.index
# Out:
# Index(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구',
#        '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '은평구', '종로구', '중구', '중랑구'],
#       dtype='object', name='구별')

# %%
import matplotlib as mpl

# %%
font_dir = ['C:/python/fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    mpl.font_manager.fontManager.addfont(font)
    # print(mpl.font_manager.FontProperties(fname=font).get_name())

# %%
mpl.rcParams['font.family'] = 'NanumBarunGothicOTF'
print(mpl.rcParams['font.family'])
# Out:
# ['NanumBarunGothicOTF']

# %%
crime_count_norm.sort_values(by='살인', ascending=False)
# Out:
#           살인    강도  강간, 강제추행        절도        폭력
# 0   1.000000  1.00  1.000000  1.000000  1.000000
# 14  0.750000  0.20  0.539792  0.633642  0.578348
# 3   0.750000  0.12  0.425606  0.649241  0.664134
# 4   0.666667  0.28  0.555363  0.784148  0.711618
# 19  0.666667  0.44  0.482699  0.721754  0.686610
# 7   0.583333  0.12  0.231834  0.427066  0.405825
# 23  0.500000  0.24  0.278547  0.539207  0.446027
# 8   0.500000  0.12  0.269896  0.573777  0.601140
# 22  0.500000  0.16  0.269896  0.454890  0.464387
# 5   0.416667  0.16  0.359862  0.596121  0.460905
# 6   0.416667  0.08  0.314879  0.586003  0.603672
# 21  0.333333  0.12  0.287197  0.600337  0.521368
# 16  0.333333  0.08  0.204152  0.377319  0.440646
# 12  0.333333  0.16  0.555363  0.636594  0.538462
# 2   0.333333  0.04  0.235294  0.327572  0.437797
# 24  0.333333  0.24  0.243945  0.589798  0.525483
# 13  0.250000  0.08  0.237024  0.432968  0.351060
# 15  0.250000  0.16  0.190311  0.381535  0.345046
# 1   0.250000  0.24  0.214533  0.679595  0.542260
# 17  0.250000  0.28  0.427336  0.853288  0.770180
# 20  0.250000  0.04  0.243945  0.398398  0.408674
# 10  0.250000  0.28  0.292388  0.522766  0.487496
# 11  0.166667  0.04  0.311419  0.475970  0.417537
# 9   0.166667  0.08  0.124567  0.325464  0.320355
# 18  0.083333  0.12  0.200692  0.568718  0.489395

# %%
plt.figure(figsize = (10,10))
sns.heatmap(crime_count_norm.sort_values(by='살인', ascending=False), annot=True, fmt='f', linewidths=.5, cmap='mako_r')
plt.title('범죄 발생(살인발생으로 정렬) - 각 항목별 최대값으로 나눠 정규화')
plt.show()
