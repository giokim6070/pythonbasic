# %%
{
  "lastBuildDate": "Tue, 28 Feb 2023 11:29:07 +0900",
  "total": 3844572,
  "start": 1,
  "display": 10,
  "items": [
    {
      "title": "<b>진주</b> 가구 만족감있던 곳",
      "link": "https://blog.naver.com/mumuru/223027118678",
      "description": "물론 저한테 전화로 털어놓은 이유는 결국 본인들하고 <b>진주</b> 가구 매장에 동행해달라는 거였고요. 이제... <b>진주</b> 가구 전문점에서 중점적으로 살펴볼 품목은 식탁과 소파였어요. 이갈이를 하기 전에 간지러워서... ",
      "bloggername": "루치의 달콤한 세상♥",
      "bloggerlink": "blog.naver.com/mumuru",
      "postdate": "20230225"
    },
    {
      "title": "<b>진주</b>삼겹살 내 뱃살만큼 푸짐했던 <b>진주</b> 부자돼지",
      "link": "https://blog.naver.com/k9149/223026379289",
      "description": "안녕하세요 메이입니당 ✨ 기분 꿀꿀할 땐 역시 고기죠ㅋㅋㅋㅋ 친구들이랑 퇴근하고 만나서 오랜만에 삼쏘 먹으러 다녀왔는데 <b>진주</b>삼겹살 잘하는 집을 찾았거든요~ <b>진주</b> 부자돼지는 혁신도시에 있어요... ",
      "bloggername": "나만의 속도로 RESTART:)",
      "bloggerlink": "blog.naver.com/k9149",
      "postdate": "20230224"
    },
    {
      "title": "<b>진주</b> 파밀리에 피아체 공급정보",
      "link": "https://blog.naver.com/weful/223018597133",
      "description": "<b>진주</b> 파밀리에 피아체 타운하우스의 경우 교통호재가 예정된 지역이라 부동산 시장에서 관심받는 건... 금일 알려드리는 이곳의 도시는 경전선 복선전철화 사업을 앞둔 신<b>진주</b> 역세권인 만큼 밝은 가치를... ",
      "bloggername": "디자인부동산컨설팅",
      "bloggerlink": "blog.naver.com/weful",
      "postdate": "20230217"
    },
    {
      "title": "충무공동 분위기 좋은 남매식당 <b>진주</b> 유명한 맛집",
      "link": "https://blog.naver.com/ladyyb/223003465947",
      "description": "남매식당 / NMSD 위치: 경남 <b>진주</b>시 영천강로119번길 27-47 지하 1층 전화번호: 0507-1353-4739 주차O 안녕하세요, <b>진주</b> 맛집 블로거 유꿀이입니다. 오늘은 오랜만에 남매식당을 다녀왔습니다. <b>진주</b> 남매식당 워낙... ",
      "bloggername": "출장러 유꿀이의 여행 리뷰٩( ᐛ )و",
      "bloggerlink": "blog.naver.com/ladyyb",
      "postdate": "20230202"
    },
    {
      "title": "<b>진주</b> 금산 칼국수 맛집 무량원",
      "link": "https://blog.naver.com/siloverk/223020483469",
      "description": "오늘은 <b>진주</b> 금산에 점심 한 끼 가볍게 먹기 좋은 칼국숫집을 소개하려고 합니다 점심 메뉴로 금산의... 식사하시고 <b>진주</b>의 마스코트 하모도 구경하는 건 어떠세요? 그럼 내돈내산 <b>진주</b> 금산 맛집 무량원... ",
      "bloggername": "은자매는 오늘도 먹어요",
      "bloggerlink": "blog.naver.com/siloverk",
      "postdate": "20230219"
    },
    {
      "title": "<b>진주</b>속눈썹 예뻐지고 편해졌어",
      "link": "https://blog.naver.com/lilyapril/223025276378",
      "description": "싶어 <b>진주</b>속눈썹 샵을 방문했어요. 전 처음 도착했을 때 카페인 줄 알았어요. 그래서 내가 잘 못... 있다니 <b>진주</b>속눈썹 샵 너무 마음에 들었어요 그리고 옥상에 루프탑이 있어서 기분 전환 하기도 좋아요.... ",
      "bloggername": "JOY WORLD",
      "bloggerlink": "blog.naver.com/lilyapril",
      "postdate": "20230223"
    },
    {
      "title": "<b>진주</b> 망경동 카페 한옥 인테리어가 예쁜 은안재",
      "link": "https://blog.naver.com/jiun2327/223026363124",
      "description": "오늘은 한옥 인테리어가 인상적인 예쁜 <b>진주</b>카페 리뷰를 해보도록 하겠다. 리뷰 할 곳의 이름은 은안재 (恩安在) 이며 이 곳은 <b>진주</b>에 많은 카페 중에서도 한옥 감성의 카페로 워낙 유명해서 나도 이름은 많이... ",
      "bloggername": "bbbbblog",
      "bloggerlink": "blog.naver.com/jiun2327",
      "postdate": "20230224"
    },
    {
      "title": "<b>진주</b>샷시 연료비 절감을 위해",
      "link": "https://blog.naver.com/hdoa8043/222999148273",
      "description": "그래서 요즘 <b>진주</b>샷시 전문적으로 시공해결가능한곳 찾으시는 분들이 유독 많아지고 있어요. 샷시는 늘... 가능한 <b>진주</b>샷시 대세창호를 통해서 바꿔보시는 것을 추천드리고 싶어요. 오래된 샷시를 그대로... ",
      "bloggername": "인테리어 탐구생활",
      "bloggerlink": "blog.naver.com/hdoa8043",
      "postdate": "20230130"
    },
    {
      "title": "<b>진주</b> 평거동 미용실 라트리헤어스파힐 <b>진주</b>베르점 단발태슬컷",
      "link": "https://blog.naver.com/tnwlwldu/223027592818",
      "description": "제가 찾은 곳은 <b>진주</b> 평거동미용실 라트리헤어에 예나 아티스트님에게 예약을 하고 갔는데요. 인스타... ㅎㅎ <b>진주</b>에서는 이미 서비스와 실력을 검증받은 매장이더라고요. 저는 왜 몰랐을까요...?? 주위 사람들은... ",
      "bloggername": "아정이의 헤어디자인",
      "bloggerlink": "blog.naver.com/tnwlwldu",
      "postdate": "20230225"
    },
    {
      "title": "<b>진주</b> 혁신 코오롱 하늘채 알아보기",
      "link": "https://blog.naver.com/mstar42/223029026867",
      "description": "<b>진주</b> 혁신도시에 위치한 코오롱 하늘채. 원래 LH4단지라 불렸는데요. 이름을 바꾸었습니다. 개인적 사정으로 실거주를 2개월 정도 했습니다. 2년 아니고 2개월입니다.^^;; LH 본사 건물과 가장 가까운 아파트가... ",
      "bloggername": "커피포리 이야기들",
      "bloggerlink": "blog.naver.com/mstar42",
      "postdate": "20230227"
    }
  ]
}
# Out:
# {'lastBuildDate': 'Tue, 28 Feb 2023 11:29:07 +0900',
#  'total': 3844572,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>진주</b> 가구 만족감있던 곳',
#    'link': 'https://blog.naver.com/mumuru/223027118678',
#    'description': '물론 저한테 전화로 털어놓은 이유는 결국 본인들하고 <b>진주</b> 가구 매장에 동행해달라는 거였고요. 이제... <b>진주</b> 가구 전문점에서 중점적으로 살펴볼 품목은 식탁과 소파였어요. 이갈이를 하기 전에 간지러워서... ',
#    'bloggername': '루치의 달콤한 세상♥',
#    'bloggerlink': 'blog.naver.com/mumuru',
#    'postdate': '20230225'},
#   {'title': '<b>진주</b>삼겹살 내 뱃살만큼 푸짐했던 <b>진주</b> 부자돼지',
#    'link': 'https://blog.naver.com/k9149/223026379289',
#    'description': '안녕하세요 메이입니당 ✨ 기분 꿀꿀할 땐 역시 고기죠ㅋㅋㅋㅋ 친구들이랑 퇴근하고 만나서 오랜만에 삼쏘 먹으러 다녀왔는데 <b>진주</b>삼겹살 잘하는 집을 찾았거든요~ <b>진주</b> 부자돼지는 혁신도시에 있어요... ',
#    'bloggername': '나만의 속도로 RESTART:)',
#    'bloggerlink': 'blog.naver.com/k9149',
#    'postdate': '20230224'},
#   {'title': '<b>진주</b> 파밀리에 피아체 공급정보',
#    'link': 'https://blog.naver.com/weful/223018597133',
# ...

# %%
import os
import sys
import urllib.request
client_id = "11mMUjt5M_Nd7ubR0lNZ"
client_secret = "l7jXbHH11j"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 28 Feb 2023 11:31:06 +0900",
# 	"total":388300,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b>자격증 취득 독학보다 학원이 좋은 이유",
# 			"link":"https:\/\/blog.naver.com\/hyunju7647\/223021791438",
# 			"description":"그래서 처음으로 코딩을 배워보기 위해 <b>파이썬<\/b>자격증을 취득하게 되었습니다. <b>파이썬<\/b>자격증을 가장 먼저 취득한 이유는 기초코딩 중에서 가장 배우기 쉽다고 해서 취득하게 되었는데요. 기초코딩에는 C언어와... ",
# 			"bloggername":"슈퍼더블디",
# 			"bloggerlink":"blog.naver.com\/hyunju7647",
# 			"postdate":"20230220"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>학원을 다니면서 공부해야하는 이유",
# 			"link":"https:\/\/blog.naver.com\/sow723\/223024072662",
# 			"description":"개발자와는 전혀 관계 없던 제가 <b>파이썬<\/b>학원을 다니면서 이 쪽으로 취업에 성공할 줄이야 아무도... 그래서 일단 비전공자도 쉽게 배울 수 있다는 언어를 배우기 위해서 #<b>파이썬<\/b>학원 을 다녀보게 되었습니다.... ",
# 			"bloggername":"Onelog",
# 			"bloggerlink":"blog.naver.com\/sow723",
# 			"postdate":"20230222"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>학원 초보자를 위한 공부과정!",
# 			"link":"https:\/\/blog.naver.com\/chzhvkdll\/222931446581",
# ...

# %%
key = "IKTXFZZJC9QIG5AZ8N8J"

# %%
#20년부터 21년까지 월별 투자자별 주식거래를 받아보았다.
import requests as rq

stock_key = '901Y055'
stock_url = f'https://ecos.bok.or.kr/api/StatisticSearch/{key}/json/kr/1/10/{stock_key}/M/202001/202112/S22B/?/?/?'

stock = rq.get(stock_url)
print(stock.status_code)
stock_dict = stock.json()
print(stock_dict['StatisticSearch']['row'][0])
# Out:
# 200
# {'STAT_CODE': '901Y055', 'STAT_NAME': '1.5.1.3. 투자자별 주식거래', 'ITEM_CODE1': 'S22B', 'ITEM_NAME1': '매수 1)', 'ITEM_CODE2': 'VO', 'ITEM_NAME2': '거래량', 'ITEM_CODE3': None, 'ITEM_NAME3': None, 'ITEM_CODE4': None, 'ITEM_NAME4': None, 'UNIT_NAME': '천주 ', 'TIME': '202001', 'DATA_VALUE': '13096066'}

# %%
stock_df = pd.DataFrame(stock_dict['StatisticSearch']['row'])
print(stock_df)
# Out:
#   STAT_CODE           STAT_NAME ITEM_CODE1 ITEM_NAME1 ITEM_CODE2 ITEM_NAME2  \
# 0   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 1   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 2   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 3   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 4   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 5   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 6   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 7   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 8   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
# 9   901Y055  1.5.1.3. 투자자별 주식거래       S22B      매수 1)         VO        거래량
#
#   ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4 UNIT_NAME    TIME DATA_VALUE
# ...

# %%
import requests
response = requests.get('http://api.kcisa.kr/openapi/service/rest/meta10/get20150059?serviceKey=db6fdf6e-742f-42ba-abf3-c88f476f4aaf&numOfRows=100&pageNo=1',
                        headers={'accept': 'application/json'})

print(response.status_code)
# Out:
# 200

# %%
print(f"인코딩: {response.encoding}") 
print(f"콘텐츠 타입: {response.headers['Content-Type']}")
print(f"서버: {response.headers['server']}")
# Out:
# 인코딩: utf-8
# 콘텐츠 타입: application/json; charset=utf-8
# 서버: nginx

# %%
response.json().keys()   #불러온 공공데이터를 제이슨 통해서 딕셔너리반환, 그것에 대한 키 값을 보여달라는 뜻
# 그랬더니 아래에 response라는 키 하나만 나옴(아래)
# Out:
# dict_keys(['response'])

# %%
import json
response.json()['response']['body']['items']['item'][0]
# Out:
# {'title': '대진교강변',
#  'alternativeTitle': None,
#  'creator': '홍천군DB',
#  'regDate': '2021-05-05 02:38:51',
#  'collectionDb': '휴양지',
#  'subjectCategory': None,
#  'subjectKeyword': None,
#  'extent': None,
#  'description': '&lt;숙박정보&gt;<br />\n그린모텔 033-435-7708<br />\n월성장 033-432-3375<br />\n일우장 033-434-3930<br />\n리버파크장 033-434-8350',
#  'spatial': '외삼포리 대진교강변',
#  'temporalCoverage': ' ',
#  'person': None,
#  'language': 'Kor',
#  'reference': '화촌면사무소 033-430-4421',
#  'referenceIdentifier': 'http://www.great.go.kr/upload/tour/IMG_5752_1.JPG',
#  'rights': None,
#  'copyrightOthers': None,
#  'url': 'http://www.great.go.kr/_theme/repose.asp?mode=view&sno=40',
#  'contributor': None}

# %%
a = response.json()['response']['body']['items']['item']

# %%
import pandas as pd
pd.DataFrame(a)
# Out:
#       title alternativeTitle creator              regDate collectionDb  \
# 0     대진교강변             None   홍천군DB  2021-05-05 02:38:51          휴양지
# 1  가리산자연휴양림             None   홍천군DB  2021-05-05 02:38:51          휴양지
# 2      개야강변             None   홍천군DB  2021-05-05 02:38:51          휴양지
# 3      수산강변             None   홍천군DB  2021-05-05 02:38:51          휴양지
# 4      밤벌강변             None   홍천군DB  2021-05-05 02:38:51          휴양지
# 5     서봉사계곡             None   홍천군DB  2021-05-05 02:38:51          휴양지
#
#   subjectCategory subjectKeyword extent  \
# 0            None           None   None
# 1            None           None   None
# 2            None           None   None
# 3            None           None   None
# 4            None           None   None
# 5            None           None   None
#
#                                          description     spatial  \
# 0  &lt;숙박정보&gt;<br />\n그린모텔 033-435-7708<br />\n월...  외삼포리 대진교강변
# ...
