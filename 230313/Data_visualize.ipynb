# %%
# Jupyter 개발 환경이 아닌 non-interactive python의 경우, matplotlib을 활용하여
# 그래프를 그리면 그 결과로 별도의 Window를 띄운다.

# 반대로 Jupyter(interactive python, ipython)에서는 웹페이지로 표현되기 때문에 별도의
# 윈도우를 띄워서 Figure를 표현할 수 없다. 
# 이런 Jupyter의 특징 때문에, 경우에 따라서 시각화 결과물인 그래프가 출력되지 
# 않는 경우가 발생
# %matplotlib 매직(magic) 명령으로 주피터 내부에 그림을 표시하도록 지정해야 한다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# matplotlib.pylot.plot(*args, **kwargs)

# 예시
# plot(x, y) # plot x and y using default line style and color

# plot(x, y, 'bo') # plot x and y using blue circle markers

# plot(y) # plot y using x as index array 0..N-1

# plot(y, 'r+') # ditto, but with red plusses

# 만약 레이블화된 데이터와 사용되지 않으면 아래와 같이 특정 가능하다
# a.plot(x1, y1, 'g^', x2, y2, 'g-')
# 반환되는 값은 괄호 안에 입력한 것들이다.

# %%
# 라인 플롯(line plot)

## x 축의 위치(tick) 

# x 축의 위치를 x틱(tick)이라고 한다.
# default는 0, 1, ... N-1 범위의 index array다.
# x tick를 지정하려면 두 개의 같은 길이의 리스트 혹은 배열 자료를 넣으면 된다.

plt.title("Plot")
plt.plot([1, 4, 9, 16])
# xtick으로 0, 1, ... N-1 범위의 index array가 기본값
plt.show()

# %%
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
# 위 그래프와 달리 x축의 값이 먼저 입력한 리스트의 값으로 바뀐 것을 확인 가능
plt.show()

# %%
## title()

# title은 플롯의 제목을 의미

# 위 예제에서 plt.title("Plot"), plt.title("x tick")을 통해 플롯 이름 지정

# %%
## show()

# show()는 플롯을 그림으로 표시

# 주피터 랩과 같이 ipython(Interactive python) 환격에서 실행할 경우
# 모든 수치를 표시하고 ipython 푸롬프트로 돌아간다.

# matplotlib.pyplot.show(*args, **kw)

# non-interacitve 모드에서는 모든 그림을 표시하고 그 그림이 닫힐 때까지 대기한다.
# 즉, 팝업창이 뜬 것에 대하여 종료를 안 하면 전부 닫기 전까지 대기상태

# %%
## 한글 폰트 사용하기 

# 한글 제목을 사용하기 위해 title()의 인수로 한글 문자열을 전달하면
# 아래와 같이 제대로 표현되지 않는다.

plt.title("한글 제목")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
### 시스템 폰트 사용하기

# Path 중간에 한글 경로가 포함되는지 꼭 확인
# 만약 있다면 이를 지양

# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)

# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname = 'C:\\Windows\\Fonts\\GOTHICB.TTF')
# fname = '원하는 폰트 경로'
plt.rcParams['font.family'] = prop.get_family()
# Out:
# ['C:\\Windows\\Fonts\\verdana.ttf', 'C:\\Windows\\Fonts\\JUICE___.TTF', 'C:\\Windows\\Fonts\\msjhbd.ttc', 'C:\\Windows\\Fonts\\LeelaUIb.ttf', 'C:\\Windows\\Fonts\\malgunsl.ttf', 'C:\\Windows\\Fonts\\segoeuisl.ttf', 'C:\\Windows\\Fonts\\constan.ttf', 'C:\\Windows\\Fonts\\batang.ttc', 'C:\\Windows\\Fonts\\CALISTBI.TTF', 'C:\\Windows\\Fonts\\BKANT.TTF', 'C:\\Windows\\Fonts\\bahnschrift.ttf', 'C:\\Windows\\Fonts\\segoeprb.ttf', 'C:\\Windows\\Fonts\\BOD_R.TTF', 'C:\\Windows\\Fonts\\Candara.ttf', 'C:\\Windows\\Fonts\\MAGNETOB.TTF', 'C:\\Windows\\Fonts\\ERASBD.TTF', 'C:\\Windows\\Fonts\\seguisbi.ttf', 'C:\\Windows\\Fonts\\BOD_I.TTF', 'C:\\Windows\\Fonts\\BELLB.TTF', 'C:\\Windows\\Fonts\\BOD_B.TTF', 'C:\\Windows\\Fonts\\sylfaen.ttf', 'C:\\Windows\\Fonts\\DUBAI-MEDIUM.TTF', 'C:\\Windows\\Fonts\\gulim.ttc', 'C:\\Windows\\Fonts\\LTYPE.TTF', 'C:\\Windows\\Fonts\\STKAITI.TTF', 'C:\\Windows\\Fonts\\FZYTK.TTF', 'C:\\Windows\\Fonts\\GIL_____.TTF', 'C:\\Windows\\Fonts\\seguibl.ttf', 'C:\\Windows\\Fon
# ...

# %%
### Font 설치하기

# 폰트 설치 방법

# 1. 폰트를 다운로드
# - 무료 폰트 사이트
# a. 눈누: https://noonnu.cc/
# b. 구글 폰트: https://fonts.google.com/
# c. 네이버 글꼴 모음: https://hangeul.naver.com/font

# 다운로드 받은 폰트를 실행하면 설치 가능
# 리눅스에서 네이버에서 제공하는 나눔 글꼴 설치하기는 방법
# 해당 방법은 Colab에서도 사용 가능

# sudo apt install -y fonts-nanum*
# sudo fc-cache -fv
# rm -/.cache/matplotlib -rf

# %%
### 외부 폰트 사용하기

# Path 중간에 한글 경로가 포함되는지 꼭 확인
# 만약 있다면 이를 지양

# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths = font_dir):
    print(mpl.font_manager.FontProperties(fname = font).get_name())
    mpl.font_manager.fontManager.addfont(font)

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'maruburi'
print(mpl.rcParams['font.family'])
# Out:
# ['maruburi']

# %%
### Font scope

# 설치된 폰트를 사용하는 방법은 크게 2가지

# 1. mpl.rc('font', family = '폰트명') 메서드를 통한 설정으로 전체 벙위에 대해 적용
#   위 코드는 mpl.rcParams['font.family'] = '폰트명'과 같다.

# 2. fontdict keyword argument를 사용하여 세부적으로 적용하는 방법

# %%
### matplotlib.pylot.rc()

# 한글 문자열은 항상 유니코드(UTF-8, cp949)를 사용해야 한다.

# mpl.rc('rcParams', 변경할 값을 키워드 인수로 전달)는 rcParams를 변경해주는 메서드

# matplotlob.pyplot.rc(group, **kwargs)

# %%
# 아래 예제는 나눔 고딕 폰트를 적용
# dict 타입의 변수를 함수(혹은 메서드)의 키워드 인수로 사용하려면 **을 붙여서 전달

global_font = {'family' : 'NanumGothic', 'size' : 12, 'weight' : 'bold'}

# 폰트설정
mpl.rc('font', **global_font) # pass in font dict as kwargs(키워드인수 = keyword arguments)
# mpl.rc('font', 'family' : 'NanumGothic', 'size' : 24, 'weight' : 'bold')와 같이 동작

# %%
import pandas as pd

# %%
# ※(참고)RcParams으로 설정할 수 있는 font 설정들
# font.cursive    font.monospace    font.serif    font.style
# font.family     font.sans-serif   font.variant  font.fantasy
# font.stretch    font.weight

data = {
    "설명" : ["필기체", "폰트", "판타지", "고정폭", "산세리프", "세리프",
           "폰트 크기", "장평", "표시 형태", "대소문자 표기법", "굵기"]
}

df = pd.DataFrame(data, index = ["cursive", "family", "fantasy", "monospace", 
                                "sans-serif", "serif", "size", "stretch",
                                "style", "variant", "weight"])
df.index.name = "attributes"
df
# Out:
#                   설명
# attributes
# cursive          필기체
# family            폰트
# fantasy          판타지
# monospace        고정폭
# sans-serif      산세리프
# serif            세리프
# size           폰트 크기
# stretch           장평
# style          표시 형태
# variant     대소문자 표기법
# weight            굵기

# %%
plt.title("한글 제목")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 레이블")
plt.ylabel("와이축 레이블")
plt.show()

# %%
title_font = {'family' : 'NanumMyeongjo', 
              'size' : 24, 
              'color' : 'black'}

xlabel_font = {'family' : 'NanumBarunpen', 
              'size' : 18,
              'weight' : 'bold',
              'color' : 'darkred'}

ylabel_font = {'family' : 'NanumBarunGothic', 
              'size' : 12,
              'weight' : 'light',
              'color' : 'blue'}

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title("한글 제목", fontdict = title_font)
plt.xlabel("엑스축 레이블", fontdict = xlabel_font)
plt.ylabel("와이축 레이블", fontdict = ylabel_font)
plt.show()
# Out:
# findfont: Font family ['NanumMyeongjo'] not found. Falling back to DejaVu Sans.
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family ['NanumBarunpen'] not found. Falling back to DejaVu Sans.
# ...

# %%
### Unicode minus 표기법 설정

# 음수 부호를 유니코드와 ASCII 중 어떤 문자로 표기할지 설정
# rc() 메서드로 RcParams 중 axes.unicode_minus=False로 변경함녀 ASCII의 문자로 표현

# 유니코드의 음수 부호설정
mpl.rc('axes', unicode_minus = False)

# %%
### Style 설정하기

# 플롯 명령어는 보는 사람이 그림을 더 알아보기 쉽게 하기 위해 다양한
# 스타일(style)을 지원한다.
# plot 명령어에서는 다음과 같이 추가 문자열 인수를 사용하여 스타일 지원

# %%
plt.title("default 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
plt.title("'rs--' 스타일의 plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rp--')
plt.show()

# %%
#### style 설정하는 순서

# 스타일 문자열은 색상(color), 마커(marker), 선 종류(line style)의 순서로 지정
# 만약 이 중 일부가 생략되면 디폴트 값이 적용

# %%
##### color 

data_color = {
    "약자" : ['k', 'w', 'r', 'b', 'g', 'c', 'm', 'y']
}

style_color = pd.DataFrame(data_color, index = ["black", "white", "red", "blue",
                                                "green", "cyan", "magenta", "yellow"])
style_color.index.name = "색 이름"
style_color
# Out:
#         약자
# 색 이름
# black    k
# white    w
# red      r
# blue     b
# green    g
# cyan     c
# magenta  m
# yellow   y

# %%
##### marker

data_marker = {
    "설명" : ['point marker', 'pixel marker', 'circle marker', 'triangle_down marker',
           'triangle_up marker', 'triangle_left marker', 'triangle_right marker',
           'hline, vline', 'star marker', 'pentagon marker', 'hexagon1 marker', 
           'hexagon2 marker', 'plus marker', 'x marker', 'diamond marker', 
           'thin_diamond marker']
}

style_marker = pd.DataFrame(data_marker, index = ['.', ',', 'o', 'v, 1', '^, 2', '<, 3',
                                                 '>, 4', '_, |', '*', 'p', 'h', 'H', '+',
                                                 'x', 'D', 'd'])
style_marker.index.name = "구분"
style_marker
# Out:
#                          설명
# 구분
# .              point marker
# ,              pixel marker
# o             circle marker
# v, 1   triangle_down marker
# ^, 2     triangle_up marker
# <, 3   triangle_left marker
# >, 4  triangle_right marker
# _, |           hline, vline
# *               star marker
# p           pentagon marker
# h           hexagon1 marker
# H           hexagon2 marker
# +               plus marker
# x                  x marker
# D            diamond marker
# d       thin_diamond marker

# %%
##### linestyle

data_linestyle = {
    "설명" : ['solid line', 'dashed line', 'dash-dotted line',
           'dotted line', 'draw nothing']
}

style_linestyle = pd.DataFrame(data_linestyle, index = ["'_' or 'solid'",
                                                       "'--' or 'dashed'",
                                                       "'-.' or 'dashdot'",
                                                       "':' or 'dotted'",
                                                       "'None', ' ', ''"])
style_linestyle.index.name = "구분"
style_linestyle
# Out:
#                                  설명
# 구분
# '_' or 'solid'           solid line
# '--' or 'dashed'        dashed line
# '-.' or 'dashdot'  dash-dotted line
# ':' or 'dotted'         dotted line
# 'None', ' ', ''        draw nothing

# %%
##### 기타 style

# 라인 플롯에서는 위 세가지 스타일 color, marker, linestyle 외에 여러가지
# 스타일을 지정할 수 있다.

data_etc = {
    "약자" : ['c', 'lw', 'ls', '', 'ms', 'mec', 'mew', 'mfc'],
    "description" : ['선 색상', '선 굵기', '선 스타일', '마커 종류',
                    '마커 크기', '마커 선 색깔', '마커 선 굵기',
                    '마커 내부 색상']
}

style_etc = pd.DataFrame(data_etc, index = ['color', 'linewidth',
                                                 'linestyle', 'marker',
                                                 'markersize', 'markeredgecolor',
                                                 'markeredgewidth', 'markerfacecolor'])
style_etc.index.name = "구분"
style_etc
# Out:
#                   약자 description
# 구분
# color              c        선 색상
# linewidth         lw        선 굵기
# linestyle         ls       선 스타일
# marker                     마커 종류
# markersize        ms       마커 크기
# markeredgecolor  mec     마커 선 색깔
# markeredgewidth  mew     마커 선 굵기
# markerfacecolor  mfc    마커 내부 색상

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c = 'b',
         lw = 5, ls = '--', marker = 'o', ms = 15, mec = 'g', mew = 5, mfc = 'r')
plt.title("스타일 적용 예")
plt.show()

# %%
### 축의 범위 설정하기

# 그림의 범위를 xlim, ylim으로 설정 가능

plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c = 'b', lw = 5, ls = '--', marker = 'o', ms = 15, mec = 'g', 
         mew = 5, mfc = 'r')
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
import numpy as np

# %%
# 틱 라벨 문자열에는 $$ 사이에 수학 문자식(Mathmatical expressions)을 
# 넣을 수도 있다.

x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.title("x축과 y축의 tick label 설정")
plt.plot(x, c)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1])
plt.show()

# %%
# 틱 라벨 문자열에는 $$ 사이에 수학 문자식(Mathmatical expressions)을 
# 넣을 수도 있다.

X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("TeX, 문자열로 tick label 정의")
plt.plot(X, C)
plt.xticks([-np.pi, np.pi / 2, 0, np.pi /2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %%
### 여러 개의 선 그리기

# 라인 플롯에는 선을 하나가 아니라 여러개를 그리고 싶은 경우
# x데이터, y데이터, 스타일 문자열을 반복하여 인수로 넘긴다.

# 이 경우에는 하나의 선을 그릴 때 처럼 x 데이터나 스타일 문자열을 생력 불가능!!!

# 딕셔너리를 키워드 인수로 바꿔줄 때  **별표 두개를 붙임.
[
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t **3, 'g^-')
plt.show()

# %%
# 여러 개의 선 그리기
plt.title("복수의 plot 명령을 한 그림에서 표현")
style1 = {"c":"b", "lw":5, "ls":"--", "marker":"o", "ms":15, "mec":"g", "mew":5, "mfc":"r"}
style2 = {"c":"k", "lw":3, "ls":"--", "marker":"s", "ms":10, "mec":"m", "mew":5, "mfc":"c"}

plt.plot([1, 4, 9, 16], **style1)
plt.plot([9, 16, 4, 1], **style2) 

plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls = "--", label = "cosine")
plt.plot(X, S, ls = ":", label = "sine")
plt.legend(loc = 2) # upper left
# plt.legend(loc = 'upper left') # 스트링으로도 값을 받는다.
plt.show()

# %%
### x, y축 label

# 플롯의 x축 위치와 y축 위치에는 각각 그 데이터가 의미하는 바를 표시하기 위해
# 라벨(label)을 추가할 수 있다.

# 라벨을 붙이려면 xlabel(), ylabel()을 사용한다.

x = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("Cosine plot")
plt.plot(X, C, label = 'cosine') 
plt.xlabel('time')
plt.ylabel('Cosine plot')plt.show()

# %%
###연습문제

a = np.arange(32, 100)
b = (a - 32) * 5 / 9
plt.title("섭씨 온도와 화씨 온도")
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.plot(a, b, "r-.")
plt.show()

# %%
## Figure

# Matplotlib는 data를 Figure(windows, jupyter widgets, etc.)에 x-y 좌표의 그래프로
# 표시(3차원은 x-y-z, 극좌표는 θ-r등). 각각의 Figure는 하나 이상의 Axes를 갖는다.
# Axes는 Figure 안에 그릴 그림의 개수이다.

# 가장 간단하게 Figure, Axes 객체를 만드는 방법은 pyplot.subplots()을 사용하는 것
# 그 후에 Axes.plot()를 활용하여 Axes에 데이터를 그린다.

fig, ax = plt.subplots() # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]) # Plot some data on the axes.
plt.show()

# %%
# Figure는 전체 그림(그래프)를 의미하는 객체
# Figure 객체는 Axes, 특수 Artist그룹(title, figure legends, colorbar, etc), 
# 그리고 심지어 중첩된 subfigures까지 포함할 수 있다.

# 가장 쉬운 방법으로 Figure 객체를 생성하는 방법들이다. 
# Axes 없이 Figure만 얻으려면 figure() 메서드를 사용하면 된다. 
# 1개의 Axes 객체를 갖는 Figure를 만들기 위해선 subplots() 메서드를 인수 없이 사용하면 된다. 
# grid 형태의 shape을 갖는 Axes 객체를 여럿 만들 땐 subplot() 메서드에 
# 첫 인수로 row를 두 번째 인수로 column을 입력

fig = plt.figure() # an empty figure with no Axes
fig, ax = plt.subplots() # a figure with a single Axes (언패킹)
fig, axs = plt.subplots(2, 2) # a figure with a 2X2 grid Axes
plt.show()

# %%
### Figure - plt.plot()

# 원래 Figure 객체를 생성하려면 figure()을 사용하여 그 반환값으로 Figure 객체를 얻어야 함
# 그러나 plot() 명령만 실행해도 자동으로 Figure 객체를 생성해주기 때문에
# 일반적으로는 figure()를 잘 사용하지 않습니다.

# figure()을 명시적으로 사용하는 경우는 여러 개의 Windows를 동시에 띄워야 하거나
# (non-interactive python), Jupyter lab 등에서(ipython) 그림의 크기를 설정하고 싶을 때
# 사용한다. 그림의 크기는 figsize 인수로 설정합니다.


np.random.seed(0)
fl = plt.figure(figsize=(10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
### plt.show()가 그래프를 그리는 방식의 차이

# ipython의 형태인 주피터 랩에서 show() 메서드를
# 통해 그래프를 그려보면 별도의 Window 객체를
# 생성하지 않고 jupyter widget으로 결과를 보여줌

# 반대로 파이썬을 독립 실행하는 경우에는 하나의
# Figure당 하나의 Window를 별도로 가진다. 
# 이 때 Matplotlib backends는 Figure windows에 대한
# 확대 및 축소 기능을 지원합니다.

# %%
### Figure - Figure 객체 얻기 plt.gcf()

f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot((1, 2, 3, 4), 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 2110726210128
# Figure(640x480) 2110726210128

# %%
## Axes

# Figure 객체 안에 여러 개의 플롯을 그리드(grid) 형태로 보여야하는 경우도 있다.
# Figure 안에 있는 각각의 플롯은 Axes라고 불리는 객체에 속함

# Figure 안에 Axes를 생성하려면 원래 subplot()을 사용하여 명시적으로 Axes 객체를
# 얻어야 한다. 그러나 plot()을 바로 사용해도 자동으로 Figure, Axes 객체를 생성해
# 준다.

# subplot()은 그리드(grid) 형태의 Axes 객체들을 생성
# Figure가 행렬(matrix)이고 Axes가 행렬의 원소라고 생각하면 됨

# 예를 들어 위와 아래 두 개의 플롯이 있는 경우 행이 2 이고 열이 1인 2x1 행렬
# subplot 명령은 세개의 인수를 가지는데 처음 두개의 원소가 전체 그리드 행렬의 모양을
# 지시하는 두 숫자이고, 세번째 인수가 네 개 중 어느것인지를 의미하는 숫자

ax1 = plt.subplot(2, 1, 1)
# 여기에서 윗부분에 그릴 플롯 명령 실행

ax2 = plt.subplot(2, 1, 2)
# 여기세어 아랫부분에 그릴 플롯 명령 실행

# %%
# 위/아래 두 개의 플롯을 하나의 Figure 안에 그리려면 다음처럼 명령을 실행해야 한다.
# 여기에서 숫자 인덱싱은 파이썬이 아닌 Matlab 관행을 따르기 때문에 첫번째 플롯을
# 가리키는 숫자가 0이 아니라 1임에 주의해야 합니다.

# tight_layout() 명령을 실행하면 플롯 간의 간격을 자동으로 맞춰준다.

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
# 만약 2x2 형태의 네 개의 플롯이라면 다음과 같이 그린다.
# 이 때 subplot 의 인수는 (2,2,1)를 줄여서 221 라는 하나의 숫자로 표시할 수도 있다. 
# Axes의 순서는 콘솔출력 순서와 동일(좌에서 우로, 위에서 아래로).

np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %%
# subplots()에 인수를 두개만 전달하면 복수의 Axes 객체를 동시에 생성할 수 있다.
# 이때는 2차원 ndarray 형태로 Axes 객체가 반환

# np.random.seed(0)

# plt.subplot(221)
# plt.plot(np.random.rand(5))
# plt.title('axes 1')

# plt.subplot(222)
# plt.plot(np.random.rand(5))
# plt.title('axes 2')

# plt.subplot(223)
# plt.plot(np.random.rand(5))
# plt.title('axes 3')

# plt.subplot(224)
# plt.plot(np.random.rand(5))
# plt.title('axes 4')

# plt.tight_layout()
# plt.show()

# 위 코드를 다르게 표현하면 아래와 같다.

fig, axes = plt.subplots(2, 2)
### subplot과 subplots 구분해서 사용하기 ###
### subplots는 인수 2개 전달함!! ###

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title('axes 1')
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title('axes 2')
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title('axes 3')
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title('axes 4')

plt.tight_layout()
plt.show()

# %%
# Axes는 데이터 플로팅을 위한 영역으로 Figure에 포함되는 Artist이다. 
# 일반적으로 2차원의 경우 Axis 객체를 두 개 포함한다.(3차원의 경우 Axis 객체를 세 개 포함)
# Axis는 ticks와 tick labels을 제공하며 이는 Axes의 데이터 범위에 대한 척도가 된다.

# - Axes와 Axis는 다른 객체이므로 잘 구분해서 봐야 합니다.

# Axes 클래스와 그 메서드는 주요한 Entry point이며, 대부분의 플로팅 메서드가 정의되어 있다.

# Inheritance
# matplotlob.artist.Artist → matplotlib.axes._base._AxesBase → matplotlib.axes._axes.Axes

# %%
# 하나의 Axes 객체는 두 개 이상의 Axis 객체를 가진다. 
# Axis 객체는 플롯의 가로축이나 세로축을 나타내는 객체
# Axis 객체는 ticks(축의 표시)과 ticklabels(눈금 레이블을 지정하는 문자열)에 대한
# 규모와 제한을 설정한다.
# ticks의 위치는 Locator 객체에 의해 결정되며, 눈금 레이블 문자열은 Formatter 객체에
# 의해 형식이 지정된다.
# Locator와 Formatter 객체를 올바르게 조합하면 매우 세밀하게 tick 위치와 labels을
# 제어할 수 있다.

# %%
# 여러가지 플롯을 하나의 Axes 객체에 표시할 때 y값의 크기가 달라서 표시하기 힘든
# 경우가 있다. 
# 이 때는 다음처럼 twinx 명령으로 대해 복수의 y 축을 가진 플롯을 만들 수 있다. 
# twinx 명령은 x 축을 공유하는 새로운 Axes 객체를 만듭니다.

fig, ax0 = plt.subplots()
ax1 = ax0.twinx()     
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label = 'y0')
ax0.set_ylabel('y0')
ax0.grid(False)

ax1.plot([100, 200, 220, 180, 120], 'g:', label = 'y1')
ax1.set_ylabel('y1')
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()

# %%
## Artist

# 기본적으로 Figure에 보이는 모든 것들을 Artist라고 한다. 
# 이는 Figure, Axes, Axis 객체도 포함
# 또 Text 객체, Line2D 객체, collections 객체, Patch 객체 등도 포함

# Figure가 렌더링될 때, 모든 Artists가 그려진다. 
# 대부분의 Artists는 하나의 Axes에 묶여 있다.
# 이러한 Artists는 여러 Axes에 공유되거나 이동할 수 없다.

# %%
## 바 차트 (카테고리화 된 것에 대한 개수를 표현....)

# x 데이터가 카테고리 값인 경우에는 bar 명령과 barh 명령으로 바 차트(bar chart)
# 시각화를 할 수 있다. 
# 가로 방향으로 바 차트를 그리려면 barh 명령을 사용

# 바 차트 작성시 주의점은 첫번째 인수인 left가 x축에서 바(bar)의 왼쪽 변의 위치를 나타냄

y = [2, 3, 1]
x = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
# 각 bar 마다 색상을 적용할 수 있다.
# 적용하고 싶은 색상을 데이터 순으로 리스트로 생성

# 생성한 리스트를 bar()의 color 키워드 인수로 전달

# 그러면 아래와 같은 색상을 갖는 바 차트를 생성 가능

y = [2, 3, 1]
x = ['가', '나', '다']
colors = ["#87CEEB", "green", "blue"]
# google 검색창에 skyblue hex 치니까 #87CEEB 나옴 이런식으로 변경ㄴㄴ 가능

plt.title("Bar Chart")
plt.bar(x, y, color = colors)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
# xerr(엑스에러)인수나 yerr(와이에러) 인수를 지정하면 에러 바(error bar)를 추가할 수 있다.

# 다음 코드에서 alpha는 투명도를 지정한다. 0이면 완전 투명, 1이면 완전 불투명

np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr = error, alpha = 0.4)
plt.xlabel('x 라벨')
plt.show()

# %%
### 연습문제

import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic
chart = titanic["alive"].value_counts()
chart.rename({"yes" : "생존자", "no" : "사망자"}, inplace = True)
chart

x = chart.index
y = chart.values

colors = ["green", "red"]
plt.title("타이타닉호 생존 여부")
plt.barh(x, y, color=colors)
plt.xlabel('인원 수')
plt.show()

# %%
### 진명님 풀이
# x = ['사망자', '생존자']
# y = [len(titanic.survived) - np.sum(titanic.survived), np.sum(titanic.survived)]
# colors = ["red", "green"]

# plt.title("타이타닉호 생존 여부")
# plt.barh(x, y, color = colors)
# plt.xlabel("인원 수")
# plt.show()


### 서현 풀이
# titanic = sns.load_dataset("titanic")

# number = [len(titanic.loc[titanic.survived == 0]), len(titanic.loc[titanic.survived == 1])]
# people = ["사망자", "생존자"]
# colors = ['red', 'green']

# plt.title("타이타닉호 생존 여부")
# plt.barh(people, number, color=colors)
# plt.xlabel("인원 수")
# plt.show()

# %%
## 파이 차트

# 카테고리 별 값의 상대적인 비교를 해야 할 때는 pie 명령으로 파이 차트(pie chart)를
# 그릴 수 있다.

labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0) # 카테고리간 이격도
# 여기에서는 '자가'를 띄움
plt.title("Pie Chart")
plt.pie(sizes, explode = explode, labels = labels, colors = colors,
        autopct = '%1.1f%%', shadow = True, startangle = 90)
                  # 소숫점 아래 첫째자리 표시한다....퍼센트 두개는 그 뒤에
                  # 퍼센트를 붙인다는 의미....
                  # 1 앞에 퍼센트는 포맷이라는 의미.
        
plt.axis('equal') # 원의 형태를 유지
plt.show()

# %%
labels = ['미성년자', '청년', '장년', '중년', '노년']
bins = [0, 20, 30, 50, 70, 100]   # 구간
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]
explode = (0.1, 0, 0, 0, 0) 

age = titanic.dropna(subset = "age").age
size = pd.cut(age, bins=bins, labels=labels).value_counts(normalize = True)

plt.pie(size, explode = explode, labels = labels, colors = colors,
        autopct = '%1.1f%%', shadow = True, startangle = 90)    
plt.axis('equal')
plt.show()

# %%
## 히스토그램

# 히스토그램을 그리기 위한 hist 명령도 있다. 
# hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받는다. 
# 반환값으로 데이터 집계 결과를 반환한다.

np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins = 10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %%
## 스캐터 플롯

# 2차원 데이터, 즉 두 개의 실수 데이터 집합의 상관관계를 살펴보려면 scatter 명령으로
# 스캐터 플롯을 그린다. 
# 스캐터 플롯의 점 하나의 위치는 데이터 하나의 x, y 값이다.

np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter(X, Y)
plt.show()

# %%
# 데이터가 2차원이 아니라 3차원 혹은 4차원인 경우에는 점 하나의 크기 혹은 색깔을
# 이용하여 다른 데이터 값을 나타낼 수도 있다. 
# 이런 차트를 버블 차트(bubble chart)라고 한다. 
# 크기는 s 인수로 색깔은 c 인수로 지정한다.

N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N)) ** 2
plt.title("Bubble Chart")
plt.scatter(x, y1, c = y2, s = y3)
plt.show()

# %%
## inshow

# 화상(image) 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터는 imshow 명령을 써서
# 2차원 자료의 크기를 색깔로 표시하는 것이다.

from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation = 'nearest', cmap = plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left = 0.35, right = 0.65, bottom = 0.35, top = 0.65)
plt.show()

# %%
# 데이터 수치를 색으로 바꾸는 함수는 칼라맵(color map)이라고 한다. 
# 칼라맵은 cmap 인수로 지정한다. 
# 사용할 수 있는 칼라맵은 plt.cm의 속성으로 포함되어 있다. 
# 아래에 일부 칼라맵을 표시하였다.

dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
# 아래 예제는 cmap 키워드 인수를 사용하여 다양한 색상으로 변경된 결과를 출력한다.

fig,axes = plt.subplots(1, 4, figsize = (12, 3),
                        subplot_kw = {'xticks' : [], 'yticks' : []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues)

axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues_r)

axes[2].set_title("plt.BrBG")
axes[2].imshow(X, interpolation = 'nearest', cmap = 'BrBG')

axes[3].set_title("plt.BrBG_r")
axes[3].imshow(X, interpolation = 'nearest', cmap = 'BrBG_r')

plt.show()

# %%
# imshow 명령은 자료의 시각화를 돕기위해 다양한 2차원 인터폴레이션을 지원한다.

methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %%
##  컨튜어 플롯 (자주 쓰이는건 아님.....)

# 입력 변수가 x, y 두 개이고 출력 변수가 z 하나인 경우에는 3차원 자료가 된다. 
# 3차원자료를 시각화하는 방법은 명암이 아닌 등고선(contour)을 사용하는 방법이다. 
# contour 혹은 contourf 명령을 사용한다. 
# contour는 등고선만 표시하고 contourf는 색깔로 표시한다. 
# 입력 변수 x, y는 그대로 사용할 수 없고 meshgrid 명령으로 그리드 포인트 행렬을 만들어야 한다.

def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha = .75, cmap = 'jet')
plt.contour(XX, YY, ZZ, colors = 'black')
plt.show()

# %%
## 3D 서피스 플롯

# 3차원 플롯은 등고선 플롯과 달리 Axes3D라는 3차원 전용 axes를 생성하여 입체적으로
# 표시
# plot_wireframe(), plot_surface() 명령을 사용한다.

from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX ** 2 + YY ** 2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title('3D Surface Plot')
ax.plot_surface(XX, YY, ZZ, rstride = 1, cstride = 1, cmap = 'hot')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1720\3938290961.py:15: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
